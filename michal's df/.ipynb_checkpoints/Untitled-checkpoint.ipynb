# %%
import pandas as pd

# %%
data = pd.read_csv("MyData.csv")

# %%
data
# Out:
#     Unnamed: 0  Time  Letters
# 0            1  2.00     1.00
# 1            2  2.50     4.00
# 2            3  2.00     2.00
# 3            4  2.00     3.00
# 4            5  2.00     7.00
# 5            6  3.00     4.00
# 6            7  3.00     7.00
# 7            8  3.00     1.00
# 8            9  5.00     1.00
# 9           10  5.00     7.00
# 10          11  6.00     5.50
# 11          12  5.50     4.00
# 12          13  6.00     2.50
# 13          14  8.00     7.00
# 14          15  8.00     1.00
# 15          16  9.00     4.00
# 16          17  8.95     3.50
# 17          18  8.50     1.25
# 18          19  8.95     4.50
# 19          20  8.50     6.75
# 20          21  8.00     4.00
# 21          22  8.00     5.00
# 22          23  8.00     3.00
# 23          24  8.00     2.00
# 24          25  8.00     6.00
# 25          26  5.50     1.25
# 26          27  5.50     6.75
# 27          28  5.00     4.00
# 28          29  5.00     5.00
# 29          30  5.00     6.00
# ...

# %%
import matplotlib.p
